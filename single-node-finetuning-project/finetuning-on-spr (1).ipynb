# %%
# !pip install intel-extension-for-transformers
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: intel-extension-for-transformers in ./.local/lib/python3.9/site-packages (1.4.2)
# Requirement already satisfied: packaging in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from intel-extension-for-transformers) (23.2)
# Requirement already satisfied: numpy in ./.local/lib/python3.9/site-packages (from intel-extension-for-transformers) (1.23.5)
# Requirement already satisfied: schema in ./.local/lib/python3.9/site-packages (from intel-extension-for-transformers) (0.7.7)
# Requirement already satisfied: pyyaml in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from intel-extension-for-transformers) (6.0.1)
# Requirement already satisfied: neural-compressor in ./.local/lib/python3.9/site-packages (from intel-extension-for-transformers) (2.6)
# Requirement already satisfied: transformers in ./.local/lib/python3.9/site-packages (from intel-extension-for-transformers) (4.42.3)
# Requirement already satisfied: deprecated>=1.2.13 in ./.local/lib/python3.9/site-packages (from neural-compressor->intel-extension-for-transformers) (1.2.14)
# Requirement already satisfied: opencv-python-headless in ./.local/lib/python3.9/site-packages (from neural-compressor->intel-extension-for-transformers) (4.10.0.84)
# Requirement already satisfied: pandas in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from neural-compressor->intel-extension-for-transformers) (2.2.2)
# Requirement already satisfied: Pillow in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from neural-compressor->intel-extension-for-transformers) (10.2.0)
# Requirement already satisfied: prettytable in ./.local/lib/python3.9/site-packages (from neural-compressor->intel-extension-for-transformers) (3.10.0)
# Requirement already satisfied: psutil in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from neural-compressor->intel-extension-for-transformers) (5.9.8)
# Requirement already satisfied: py-cpuinfo in ./.local/lib/python3.9/site-packages (from neural-compressor->intel-extension-for-transformers) (9.0.0)
# Requirement already satisfied: requests in ./.local/lib/python3.9/site-packages (from neural-compressor->intel-extension-for-transformers) (2.32.3)
# Requirement already satisfied: scikit-learn in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from neural-compressor->intel-extension-for-transformers) (1.4.0)
# Requirement already satisfied: pycocotools in ./.local/lib/python3.9/site-packages (from neural-compressor->intel-extension-for-transformers) (2.0.8)
# Requirement already satisfied: filelock in ./.local/lib/python3.9/site-packages (from transformers->intel-extension-for-transformers) (3.15.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in ./.local/lib/python3.9/site-packages (from transformers->intel-extension-for-transformers) (0.23.4)
# Requirement already satisfied: regex!=2019.12.17 in ./.local/lib/python3.9/site-packages (from transformers->intel-extension-for-transformers) (2024.5.15)
# Requirement already satisfied: safetensors>=0.4.1 in ./.local/lib/python3.9/site-packages (from transformers->intel-extension-for-transformers) (0.4.3)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in ./.local/lib/python3.9/site-packages (from transformers->intel-extension-for-transformers) (0.19.1)
# Requirement already satisfied: tqdm>=4.27 in ./.local/lib/python3.9/site-packages (from transformers->intel-extension-for-transformers) (4.66.4)
# Requirement already satisfied: wrapt<2,>=1.10 in ./.local/lib/python3.9/site-packages (from deprecated>=1.2.13->neural-compressor->intel-extension-for-transformers) (1.16.0)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.local/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers->intel-extension-for-transformers) (2024.5.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.local/lib/python3.9/site-packages (from huggingface-hub<1.0,>=0.23.2->transformers->intel-extension-for-transformers) (4.12.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from pandas->neural-compressor->intel-extension-for-transformers) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from pandas->neural-compressor->intel-extension-for-transformers) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from pandas->neural-compressor->intel-extension-for-transformers) (2023.4)
# Requirement already satisfied: wcwidth in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from prettytable->neural-compressor->intel-extension-for-transformers) (0.2.13)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from pycocotools->neural-compressor->intel-extension-for-transformers) (3.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from requests->neural-compressor->intel-extension-for-transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from requests->neural-compressor->intel-extension-for-transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from requests->neural-compressor->intel-extension-for-transformers) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from requests->neural-compressor->intel-extension-for-transformers) (2024.2.2)
# Requirement already satisfied: scipy>=1.6.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from scikit-learn->neural-compressor->intel-extension-for-transformers) (1.10.1)
# Requirement already satisfied: joblib>=1.2.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from scikit-learn->neural-compressor->intel-extension-for-transformers) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from scikit-learn->neural-compressor->intel-extension-for-transformers) (3.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel-extension-for-transformers) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel-extension-for-transformers) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel-extension-for-transformers) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel-extension-for-transformers) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel-extension-for-transformers) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->intel-extension-for-transformers) (6.1.1)
# Requirement already satisfied: six>=1.5 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas->neural-compressor->intel-extension-for-transformers) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib>=2.1.0->pycocotools->neural-compressor->intel-extension-for-transformers) (3.17.0)

# %%
# !pip install -r requirements-finetuning.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: accelerate in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 1)) (0.28.0)
# Requirement already satisfied: cchardet in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 2)) (2.1.7)
# Requirement already satisfied: einops in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 3)) (0.8.0)
# Requirement already satisfied: evaluate in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 4)) (0.4.2)
# Requirement already satisfied: fastapi in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 5)) (0.111.0)
# Requirement already satisfied: fschat==0.2.35 in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 6)) (0.2.35)
# Requirement already satisfied: huggingface_hub in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 7)) (0.23.4)
# Requirement already satisfied: intel_extension_for_pytorch==2.3.0 in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 8)) (2.3.0+cpu)
# Requirement already satisfied: lm-eval in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 9)) (0.4.3)
# Requirement already satisfied: neural-compressor in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 10)) (2.6)
# Requirement already satisfied: neural_speed==1.0a0 in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 11)) (1.0a0)
# Requirement already satisfied: numpy==1.23.5 in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 12)) (1.23.5)
# Requirement already satisfied: onnx>=1.15.0 in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 13)) (1.16.1)
# Requirement already satisfied: optimum in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 14)) (1.21.2)
# Requirement already satisfied: optimum-intel in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 15)) (1.18.1)
# Requirement already satisfied: peft==0.6.2 in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 16)) (0.6.2)
# Requirement already satisfied: pydantic==1.10.13 in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 17)) (1.10.13)
# Requirement already satisfied: python-dotenv in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 18)) (1.0.1)
# Requirement already satisfied: python-multipart in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 19)) (0.0.9)
# Requirement already satisfied: rouge_score in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 20)) (0.1.2)
# Requirement already satisfied: sacremoses in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 21)) (0.1.1)
# Requirement already satisfied: shortuuid in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 22)) (1.0.13)
# Requirement already satisfied: starlette in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 23)) (0.37.2)
# Requirement already satisfied: tensorflow>=2.13.0 in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 24)) (2.16.2)
# Requirement already satisfied: torch==2.3.0 in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 25)) (2.3.0)
# Requirement already satisfied: torchaudio==2.3.0 in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 26)) (2.3.0)
# Requirement already satisfied: transformers>=4.35.2 in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 27)) (4.42.3)
# Requirement already satisfied: transformers_stream_generator in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 28)) (0.0.5)
# Requirement already satisfied: uvicorn in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 29)) (0.30.1)
# Requirement already satisfied: vllm in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 30)) (0.2.5)
# Requirement already satisfied: yacs in ./.local/lib/python3.9/site-packages (from -r requirements-finetuning.txt (line 31)) (0.1.8)
# Requirement already satisfied: aiohttp in ./.local/lib/python3.9/site-packages (from fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (3.9.5)
# Requirement already satisfied: httpx in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (0.27.0)
# Requirement already satisfied: markdown2[all] in ./.local/lib/python3.9/site-packages (from fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (2.4.13)
# Requirement already satisfied: nh3 in ./.local/lib/python3.9/site-packages (from fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (0.2.18)
# Requirement already satisfied: prompt-toolkit>=3.0.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (3.0.42)
# Requirement already satisfied: requests in ./.local/lib/python3.9/site-packages (from fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (2.32.3)
# Requirement already satisfied: rich>=10.0.0 in ./.local/lib/python3.9/site-packages (from fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (13.7.1)
# Requirement already satisfied: tiktoken in ./.local/lib/python3.9/site-packages (from fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (0.4.0)
# Requirement already satisfied: psutil in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from intel_extension_for_pytorch==2.3.0->-r requirements-finetuning.txt (line 8)) (5.9.8)
# Requirement already satisfied: packaging in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from intel_extension_for_pytorch==2.3.0->-r requirements-finetuning.txt (line 8)) (23.2)
# Requirement already satisfied: pyyaml in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from peft==0.6.2->-r requirements-finetuning.txt (line 16)) (6.0.1)
# Requirement already satisfied: tqdm in ./.local/lib/python3.9/site-packages (from peft==0.6.2->-r requirements-finetuning.txt (line 16)) (4.66.4)
# Requirement already satisfied: safetensors in ./.local/lib/python3.9/site-packages (from peft==0.6.2->-r requirements-finetuning.txt (line 16)) (0.4.3)
# Requirement already satisfied: typing-extensions>=4.2.0 in ./.local/lib/python3.9/site-packages (from pydantic==1.10.13->-r requirements-finetuning.txt (line 17)) (4.12.2)
# Requirement already satisfied: filelock in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (3.15.4)
# Requirement already satisfied: sympy in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (1.13.0)
# Requirement already satisfied: networkx in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (3.1.3)
# Requirement already satisfied: fsspec in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (2024.5.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (12.1.105)
# Requirement already satisfied: triton==2.3.0 in ./.local/lib/python3.9/site-packages (from torch==2.3.0->-r requirements-finetuning.txt (line 25)) (2.3.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in ./.local/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch==2.3.0->-r requirements-finetuning.txt (line 25)) (12.5.82)
# Requirement already satisfied: datasets>=2.0.0 in ./.local/lib/python3.9/site-packages (from evaluate->-r requirements-finetuning.txt (line 4)) (2.20.0)
# Requirement already satisfied: dill in ./.local/lib/python3.9/site-packages (from evaluate->-r requirements-finetuning.txt (line 4)) (0.3.8)
# Requirement already satisfied: pandas in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from evaluate->-r requirements-finetuning.txt (line 4)) (2.2.2)
# Requirement already satisfied: xxhash in ./.local/lib/python3.9/site-packages (from evaluate->-r requirements-finetuning.txt (line 4)) (3.4.1)
# Requirement already satisfied: multiprocess in ./.local/lib/python3.9/site-packages (from evaluate->-r requirements-finetuning.txt (line 4)) (0.70.16)
# Requirement already satisfied: fastapi-cli>=0.0.2 in ./.local/lib/python3.9/site-packages (from fastapi->-r requirements-finetuning.txt (line 5)) (0.0.4)
# Requirement already satisfied: ujson!=4.0.2,!=4.1.0,!=4.2.0,!=4.3.0,!=5.0.0,!=5.1.0,>=4.0.1 in ./.local/lib/python3.9/site-packages (from fastapi->-r requirements-finetuning.txt (line 5)) (5.10.0)
# Requirement already satisfied: orjson>=3.2.1 in ./.local/lib/python3.9/site-packages (from fastapi->-r requirements-finetuning.txt (line 5)) (3.10.6)
# Requirement already satisfied: email_validator>=2.0.0 in ./.local/lib/python3.9/site-packages (from fastapi->-r requirements-finetuning.txt (line 5)) (2.2.0)
# Requirement already satisfied: jsonlines in ./.local/lib/python3.9/site-packages (from lm-eval->-r requirements-finetuning.txt (line 9)) (4.0.0)
# Requirement already satisfied: numexpr in ./.local/lib/python3.9/site-packages (from lm-eval->-r requirements-finetuning.txt (line 9)) (2.10.1)
# Requirement already satisfied: pybind11>=2.6.2 in ./.local/lib/python3.9/site-packages (from lm-eval->-r requirements-finetuning.txt (line 9)) (2.13.1)
# Requirement already satisfied: pytablewriter in ./.local/lib/python3.9/site-packages (from lm-eval->-r requirements-finetuning.txt (line 9)) (1.2.0)
# Requirement already satisfied: sacrebleu>=1.5.0 in ./.local/lib/python3.9/site-packages (from lm-eval->-r requirements-finetuning.txt (line 9)) (2.4.2)
# Requirement already satisfied: scikit-learn>=0.24.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from lm-eval->-r requirements-finetuning.txt (line 9)) (1.4.0)
# Requirement already satisfied: sqlitedict in ./.local/lib/python3.9/site-packages (from lm-eval->-r requirements-finetuning.txt (line 9)) (2.1.0)
# Requirement already satisfied: tqdm-multiprocess in ./.local/lib/python3.9/site-packages (from lm-eval->-r requirements-finetuning.txt (line 9)) (0.0.11)
# Requirement already satisfied: zstandard in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from lm-eval->-r requirements-finetuning.txt (line 9)) (0.22.0)
# Requirement already satisfied: word2number in ./.local/lib/python3.9/site-packages (from lm-eval->-r requirements-finetuning.txt (line 9)) (1.1)
# Requirement already satisfied: more-itertools in ./.local/lib/python3.9/site-packages (from lm-eval->-r requirements-finetuning.txt (line 9)) (10.3.0)
# Requirement already satisfied: deprecated>=1.2.13 in ./.local/lib/python3.9/site-packages (from neural-compressor->-r requirements-finetuning.txt (line 10)) (1.2.14)
# Requirement already satisfied: opencv-python-headless in ./.local/lib/python3.9/site-packages (from neural-compressor->-r requirements-finetuning.txt (line 10)) (4.10.0.84)
# Requirement already satisfied: Pillow in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from neural-compressor->-r requirements-finetuning.txt (line 10)) (10.2.0)
# Requirement already satisfied: prettytable in ./.local/lib/python3.9/site-packages (from neural-compressor->-r requirements-finetuning.txt (line 10)) (3.10.0)
# Requirement already satisfied: py-cpuinfo in ./.local/lib/python3.9/site-packages (from neural-compressor->-r requirements-finetuning.txt (line 10)) (9.0.0)
# Requirement already satisfied: schema in ./.local/lib/python3.9/site-packages (from neural-compressor->-r requirements-finetuning.txt (line 10)) (0.7.7)
# Requirement already satisfied: pycocotools in ./.local/lib/python3.9/site-packages (from neural-compressor->-r requirements-finetuning.txt (line 10)) (2.0.8)
# Requirement already satisfied: protobuf>=3.20.2 in ./.local/lib/python3.9/site-packages (from onnx>=1.15.0->-r requirements-finetuning.txt (line 13)) (4.25.3)
# Requirement already satisfied: coloredlogs in ./.local/lib/python3.9/site-packages (from optimum->-r requirements-finetuning.txt (line 14)) (15.0.1)
# Requirement already satisfied: sentencepiece in ./.local/lib/python3.9/site-packages (from optimum-intel->-r requirements-finetuning.txt (line 15)) (0.2.0)
# Requirement already satisfied: setuptools in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from optimum-intel->-r requirements-finetuning.txt (line 15)) (69.1.0)
# Requirement already satisfied: scipy in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from optimum-intel->-r requirements-finetuning.txt (line 15)) (1.10.1)
# Requirement already satisfied: absl-py in ./.local/lib/python3.9/site-packages (from rouge_score->-r requirements-finetuning.txt (line 20)) (2.1.0)
# Requirement already satisfied: nltk in ./.local/lib/python3.9/site-packages (from rouge_score->-r requirements-finetuning.txt (line 20)) (3.8.1)
# Requirement already satisfied: six>=1.14.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from rouge_score->-r requirements-finetuning.txt (line 20)) (1.16.0)
# Requirement already satisfied: regex in ./.local/lib/python3.9/site-packages (from sacremoses->-r requirements-finetuning.txt (line 21)) (2024.5.15)
# Requirement already satisfied: click in ./.local/lib/python3.9/site-packages (from sacremoses->-r requirements-finetuning.txt (line 21)) (8.1.7)
# Requirement already satisfied: joblib in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from sacremoses->-r requirements-finetuning.txt (line 21)) (1.3.2)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from starlette->-r requirements-finetuning.txt (line 23)) (4.3.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (3.3.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (2.4.0)
# Requirement already satisfied: wrapt>=1.11.0 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (1.65.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.local/lib/python3.9/site-packages (from tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (0.37.1)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in ./.local/lib/python3.9/site-packages (from transformers>=4.35.2->-r requirements-finetuning.txt (line 27)) (0.19.1)
# Requirement already satisfied: h11>=0.8 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from uvicorn->-r requirements-finetuning.txt (line 29)) (0.14.0)
# Requirement already satisfied: ninja in ./.local/lib/python3.9/site-packages (from vllm->-r requirements-finetuning.txt (line 30)) (1.11.1.1)
# Requirement already satisfied: ray>=2.5.1 in ./.local/lib/python3.9/site-packages (from vllm->-r requirements-finetuning.txt (line 30)) (2.32.0)
# Requirement already satisfied: pyarrow in ./.local/lib/python3.9/site-packages (from vllm->-r requirements-finetuning.txt (line 30)) (16.1.0)
# Requirement already satisfied: xformers>=0.0.23 in ./.local/lib/python3.9/site-packages (from vllm->-r requirements-finetuning.txt (line 30)) (0.0.26.post1)
# Requirement already satisfied: aioprometheus[starlette] in ./.local/lib/python3.9/site-packages (from vllm->-r requirements-finetuning.txt (line 30)) (23.12.0)
# Requirement already satisfied: idna>=2.8 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette->-r requirements-finetuning.txt (line 23)) (3.6)
# Requirement already satisfied: sniffio>=1.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette->-r requirements-finetuning.txt (line 23)) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from anyio<5,>=3.4.0->starlette->-r requirements-finetuning.txt (line 23)) (1.2.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (0.42.0)
# Requirement already satisfied: pyarrow-hotfix in ./.local/lib/python3.9/site-packages (from datasets>=2.0.0->evaluate->-r requirements-finetuning.txt (line 4)) (0.6)
# Requirement already satisfied: dnspython>=2.0.0 in ./.local/lib/python3.9/site-packages (from email_validator>=2.0.0->fastapi->-r requirements-finetuning.txt (line 5)) (2.6.1)
# Requirement already satisfied: typer>=0.12.3 in ./.local/lib/python3.9/site-packages (from fastapi-cli>=0.0.2->fastapi->-r requirements-finetuning.txt (line 5)) (0.12.3)
# Requirement already satisfied: aiosignal>=1.1.2 in ./.local/lib/python3.9/site-packages (from aiohttp->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from aiohttp->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in ./.local/lib/python3.9/site-packages (from aiohttp->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in ./.local/lib/python3.9/site-packages (from aiohttp->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in ./.local/lib/python3.9/site-packages (from aiohttp->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in ./.local/lib/python3.9/site-packages (from aiohttp->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (4.0.3)
# Requirement already satisfied: certifi in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from httpx->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (2024.2.2)
# Requirement already satisfied: httpcore==1.* in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from httpx->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (1.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from jinja2->torch==2.3.0->-r requirements-finetuning.txt (line 25)) (2.1.4)
# Requirement already satisfied: namex in ./.local/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (0.0.8)
# Requirement already satisfied: optree in ./.local/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (0.12.1)
# Requirement already satisfied: wcwidth in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from prompt-toolkit>=3.0.0->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (0.2.13)
# Requirement already satisfied: jsonschema in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from ray>=2.5.1->vllm->-r requirements-finetuning.txt (line 30)) (4.21.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in ./.local/lib/python3.9/site-packages (from ray>=2.5.1->vllm->-r requirements-finetuning.txt (line 30)) (1.0.8)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from requests->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from requests->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (2.2.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.local/lib/python3.9/site-packages (from rich>=10.0.0->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from rich>=10.0.0->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (2.17.2)
# Requirement already satisfied: portalocker in ./.local/lib/python3.9/site-packages (from sacrebleu>=1.5.0->lm-eval->-r requirements-finetuning.txt (line 9)) (2.10.0)
# Requirement already satisfied: tabulate>=0.8.9 in ./.local/lib/python3.9/site-packages (from sacrebleu>=1.5.0->lm-eval->-r requirements-finetuning.txt (line 9)) (0.9.0)
# Requirement already satisfied: colorama in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from sacrebleu>=1.5.0->lm-eval->-r requirements-finetuning.txt (line 9)) (0.4.6)
# Requirement already satisfied: lxml in ./.local/lib/python3.9/site-packages (from sacrebleu>=1.5.0->lm-eval->-r requirements-finetuning.txt (line 9)) (5.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from scikit-learn>=0.24.1->lm-eval->-r requirements-finetuning.txt (line 9)) (3.3.0)
# Requirement already satisfied: markdown>=2.6.8 in ./.local/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.local/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.local/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (3.0.3)
# Requirement already satisfied: httptools>=0.5.0 in ./.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.12.0->fastapi->-r requirements-finetuning.txt (line 5)) (0.6.1)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in ./.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.12.0->fastapi->-r requirements-finetuning.txt (line 5)) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in ./.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.12.0->fastapi->-r requirements-finetuning.txt (line 5)) (0.22.0)
# Requirement already satisfied: websockets>=10.4 in ./.local/lib/python3.9/site-packages (from uvicorn[standard]>=0.12.0->fastapi->-r requirements-finetuning.txt (line 5)) (12.0)
# Requirement already satisfied: quantile-python>=1.1 in ./.local/lib/python3.9/site-packages (from aioprometheus[starlette]->vllm->-r requirements-finetuning.txt (line 30)) (1.1)
# Requirement already satisfied: humanfriendly>=9.1 in ./.local/lib/python3.9/site-packages (from coloredlogs->optimum->-r requirements-finetuning.txt (line 14)) (10.0)
# Requirement already satisfied: wavedrom in ./.local/lib/python3.9/site-packages (from markdown2[all]->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (2.0.3.post3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from pandas->evaluate->-r requirements-finetuning.txt (line 4)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from pandas->evaluate->-r requirements-finetuning.txt (line 4)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from pandas->evaluate->-r requirements-finetuning.txt (line 4)) (2023.4)
# Requirement already satisfied: matplotlib>=2.1.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from pycocotools->neural-compressor->-r requirements-finetuning.txt (line 10)) (3.8.2)
# Requirement already satisfied: DataProperty<2,>=1.0.1 in ./.local/lib/python3.9/site-packages (from pytablewriter->lm-eval->-r requirements-finetuning.txt (line 9)) (1.0.1)
# Requirement already satisfied: mbstrdecoder<2,>=1.0.0 in ./.local/lib/python3.9/site-packages (from pytablewriter->lm-eval->-r requirements-finetuning.txt (line 9)) (1.1.3)
# Requirement already satisfied: pathvalidate<4,>=2.3.0 in ./.local/lib/python3.9/site-packages (from pytablewriter->lm-eval->-r requirements-finetuning.txt (line 9)) (3.2.0)
# Requirement already satisfied: tabledata<2,>=1.3.1 in ./.local/lib/python3.9/site-packages (from pytablewriter->lm-eval->-r requirements-finetuning.txt (line 9)) (1.3.3)
# Requirement already satisfied: tcolorpy<1,>=0.0.5 in ./.local/lib/python3.9/site-packages (from pytablewriter->lm-eval->-r requirements-finetuning.txt (line 9)) (0.1.6)
# Requirement already satisfied: typepy<2,>=1.3.2 in ./.local/lib/python3.9/site-packages (from typepy[datetime]<2,>=1.3.2->pytablewriter->lm-eval->-r requirements-finetuning.txt (line 9)) (1.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in ./.local/lib/python3.9/site-packages (from sympy->torch==2.3.0->-r requirements-finetuning.txt (line 25)) (1.3.0)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (7.0.2)
# Requirement already satisfied: mdurl~=0.1 in ./.local/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich>=10.0.0->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->-r requirements-finetuning.txt (line 10)) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->-r requirements-finetuning.txt (line 10)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->-r requirements-finetuning.txt (line 10)) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->-r requirements-finetuning.txt (line 10)) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->-r requirements-finetuning.txt (line 10)) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from matplotlib>=2.1.0->pycocotools->neural-compressor->-r requirements-finetuning.txt (line 10)) (6.1.1)
# Requirement already satisfied: chardet<6,>=3.0.4 in ./.local/lib/python3.9/site-packages (from mbstrdecoder<2,>=1.0.0->pytablewriter->lm-eval->-r requirements-finetuning.txt (line 9)) (5.2.0)
# Requirement already satisfied: shellingham>=1.3.0 in ./.local/lib/python3.9/site-packages (from typer>=0.12.3->fastapi-cli>=0.0.2->fastapi->-r requirements-finetuning.txt (line 5)) (1.5.4)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from jsonschema->ray>=2.5.1->vllm->-r requirements-finetuning.txt (line 30)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from jsonschema->ray>=2.5.1->vllm->-r requirements-finetuning.txt (line 30)) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from jsonschema->ray>=2.5.1->vllm->-r requirements-finetuning.txt (line 30)) (0.18.0)
# Requirement already satisfied: svgwrite in ./.local/lib/python3.9/site-packages (from wavedrom->markdown2[all]->fschat==0.2.35->-r requirements-finetuning.txt (line 6)) (1.4.3)
# Requirement already satisfied: zipp>=0.5 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow>=2.13.0->-r requirements-finetuning.txt (line 24)) (3.17.0)

# %%
# !pip install tf-keras
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tf-keras in ./.local/lib/python3.9/site-packages (2.16.0)
# Requirement already satisfied: tensorflow<2.17,>=2.16 in ./.local/lib/python3.9/site-packages (from tf-keras) (2.16.2)
# Requirement already satisfied: absl-py>=1.0.0 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (0.2.0)
# Requirement already satisfied: h5py>=3.10.0 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (3.11.0)
# Requirement already satisfied: libclang>=13.0.0 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (18.1.1)
# Requirement already satisfied: ml-dtypes~=0.3.1 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (0.3.2)
# Requirement already satisfied: opt-einsum>=2.3.2 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (3.3.0)
# Requirement already satisfied: packaging in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (4.25.3)
# Requirement already satisfied: requests<3,>=2.21.0 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (2.32.3)
# Requirement already satisfied: setuptools in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (69.1.0)
# Requirement already satisfied: six>=1.12.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (1.65.0)
# Requirement already satisfied: tensorboard<2.17,>=2.16 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (2.16.2)
# Requirement already satisfied: keras>=3.0.0 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (3.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (0.37.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in ./.local/lib/python3.9/site-packages (from tensorflow<2.17,>=2.16->tf-keras) (1.23.5)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow<2.17,>=2.16->tf-keras) (0.42.0)
# Requirement already satisfied: rich in ./.local/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras) (13.7.1)
# Requirement already satisfied: namex in ./.local/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras) (0.0.8)
# Requirement already satisfied: optree in ./.local/lib/python3.9/site-packages (from keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras) (0.12.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorflow<2.17,>=2.16->tf-keras) (2024.2.2)
# Requirement already satisfied: markdown>=2.6.8 in ./.local/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in ./.local/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in ./.local/lib/python3.9/site-packages (from tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras) (3.0.3)
# Requirement already satisfied: importlib-metadata>=4.4 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras) (7.0.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras) (2.1.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in ./.local/lib/python3.9/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras) (2.17.2)
# Requirement already satisfied: zipp>=0.5 in /opt/intel/oneapi/intelpython/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<2.17,>=2.16->tensorflow<2.17,>=2.16->tf-keras) (3.17.0)
# Requirement already satisfied: mdurl~=0.1 in ./.local/lib/python3.9/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.0.0->tensorflow<2.17,>=2.16->tf-keras) (0.1.2)

# %%
from transformers import TrainingArguments
from intel_extension_for_transformers.neural_chat.config import (
    ModelArguments,
    DataArguments,
    FinetuningArguments,
    TextGenerationFinetuningConfig,
)
from intel_extension_for_transformers.neural_chat.chatbot import finetune_model
model_args = ModelArguments(model_name_or_path="TinyLlama/TinyLlama-1.1B-Chat-v0.1")
data_args = DataArguments(train_file="alpaca_data.json", validation_split_percentage=1)
training_args = TrainingArguments(
    output_dir='./tmp1',
    do_train=True,
    do_eval=True,
    num_train_epochs=3,
    overwrite_output_dir=True,
    per_device_train_batch_size=4,
    per_device_eval_batch_size=4,
    gradient_accumulation_steps=2,
    save_strategy="no",
    log_level="info",
    save_total_limit=2,
    bf16=True,
)
finetune_args = FinetuningArguments()
finetune_cfg = TextGenerationFinetuningConfig(
            model_args=model_args,
            data_args=data_args,
            training_args=training_args,
            finetune_args=finetune_args,
        )
finetune_model(finetune_cfg)
# Out:
# 2024-07-12 09:04:15.043676: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-07-12 09:04:15.059197: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:479] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-12 09:04:15.081418: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:10575] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-12 09:04:15.081451: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1442] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-07-12 09:04:15.095944: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX512_FP16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-07-12 09:04:16.752408: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.local/lib/python3.9/site-packages/transformers/training_args.py:1509: FutureWarning: using `no_cuda` is deprecated and will be removed in version 5.0 of 🤗 Transformers. Use `use_cpu` instead
#   warnings.warn(
# 2024-07-12 09:04:19,183 - _logger.py - intel_extension_for_transformers.transformers.llm.finetuning.finetuning - WARNING - Process rank: 0, device: cpu
# distributed training: True, 16-bits training: True
# 2024-07-12 09:04:19,186 - finetuning.py - intel_extension_for_transformers.transformers.llm.finetuning.finetuning - INFO - Training/evaluation parameters TrainingArguments(
# _n_gpu=0,
# accelerator_config={'split_batches': False, 'dispatch_batches': None, 'even_batches': True, 'use_seedable_sampler': True, 'non_blocking': False, 'gradient_accumulation_kwargs': None, 'use_configured_state': False},
# adafactor=False,
# adam_beta1=0.9,
# adam_beta2=0.999,
# adam_epsilon=1e-08,
# auto_find_batch_size=False,
# batch_eval_metrics=False,
# bf16=True,
# bf16_full_eval=False,
# data_seed=None,
# dataloader_drop_last=False,
# dataloader_num_workers=0,
# dataloader_persistent_workers=False,
# dataloader_pin_memory=False,
# dataloader_prefetch_factor=None,
# ddp_backend=None,
# ddp_broadcast_buffers=None,
# ddp_bucket_cap_mb=None,
# ddp_find_unused_parameters=None,
# ddp_timeout=1800,
# debug=[],
# deepspeed=None,
# disable_tqdm=False,
# dispatch_batches=None,
# do_eval=True,
# do_predict=False,
# do_train=True,
# eval_accumulation_steps=None,
# eval_delay=0,
# eval_do_concat_batches=True,
# eval_on_start=False,
# eval_steps=None,
# eval_strategy=no,
# evaluation_strategy=None,
# fp16=False,
# fp16_backend=auto,
# fp16_full_eval=False,
# fp16_opt_level=O1,
# fsdp=[],
# fsdp_config={'min_num_params': 0, 'xla': False, 'xla_fsdp_v2': False, 'xla_fsdp_grad_ckpt': False},
# fsdp_min_num_params=0,
# fsdp_transformer_layer_cls_to_wrap=None,
# full_determinism=False,
# gradient_accumulation_steps=2,
# gradient_checkpointing=False,
# gradient_checkpointing_kwargs=None,
# greater_is_better=None,
# group_by_length=False,
# half_precision_backend=auto,
# hub_always_push=False,
# hub_model_id=None,
# hub_private_repo=False,
# hub_strategy=every_save,
# hub_token=<HUB_TOKEN>,
# ignore_data_skip=False,
# include_inputs_for_metrics=False,
# include_num_input_tokens_seen=False,
# include_tokens_per_second=False,
# jit_mode_eval=False,
# label_names=None,
# label_smoothing_factor=0.0,
# learning_rate=5e-05,
# length_column_name=length,
# load_best_model_at_end=False,
# local_rank=0,
# log_level=info,
# log_level_replica=warning,
# log_on_each_node=True,
# logging_dir=./tmp1/runs/Jul12_09-04-14_idc-training-gpu-compute-06,
# logging_first_step=False,
# logging_nan_inf_filter=True,
# logging_steps=500,
# logging_strategy=steps,
# lr_scheduler_kwargs={},
# lr_scheduler_type=linear,
# max_grad_norm=1.0,
# max_steps=-1,
# metric_for_best_model=None,
# mp_parameters=,
# neftune_noise_alpha=None,
# no_cuda=True,
# num_train_epochs=3,
# optim=adamw_torch,
# optim_args=None,
# optim_target_modules=None,
# output_dir=./tmp1,
# overwrite_output_dir=True,
# past_index=-1,
# per_device_eval_batch_size=4,
# per_device_train_batch_size=4,
# prediction_loss_only=False,
# push_to_hub=False,
# push_to_hub_model_id=None,
# push_to_hub_organization=None,
# push_to_hub_token=<PUSH_TO_HUB_TOKEN>,
# ray_scope=last,
# remove_unused_columns=True,
# report_to=['tensorboard'],
# restore_callback_states_from_checkpoint=False,
# resume_from_checkpoint=None,
# run_name=./tmp1,
# save_on_each_node=False,
# save_only_model=False,
# save_safetensors=True,
# save_steps=500,
# save_strategy=no,
# save_total_limit=2,
# seed=42,
# skip_memory_metrics=True,
# split_batches=None,
# tf32=None,
# torch_compile=False,
# torch_compile_backend=None,
# torch_compile_mode=None,
# torchdynamo=None,
# tpu_metrics_debug=False,
# tpu_num_cores=None,
# use_cpu=True,
# use_ipex=False,
# use_legacy_prediction_loop=False,
# use_mps_device=False,
# warmup_ratio=0.0,
# warmup_steps=0,
# weight_decay=0.0,
# )
# [INFO|configuration_utils.py:733] 2024-07-12 09:04:19,757 >> loading configuration file config.json from cache at /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/hub/models--TinyLlama--TinyLlama-1.1B-Chat-v0.1/snapshots/7abc14e7779eabc3a028bc695342869d0410dea2/config.json
# [INFO|configuration_utils.py:800] 2024-07-12 09:04:19,765 >> Model config LlamaConfig {
#   "_name_or_path": "TinyLlama/TinyLlama-1.1B-Chat-v0.1",
#   "architectures": [
#     "LlamaForCausalLM"
#   ],
#   "attention_bias": false,
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "silu",
#   "hidden_size": 2048,
#   "initializer_range": 0.02,
#   "intermediate_size": 5632,
#   "max_position_embeddings": 2048,
#   "mlp_bias": false,
#   "model_type": "llama",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 22,
#   "num_key_value_heads": 4,
#   "pretraining_tp": 1,
#   "rms_norm_eps": 1e-05,
#   "rope_scaling": null,
#   "rope_theta": 10000.0,
#   "tie_word_embeddings": false,
#   "torch_dtype": "float32",
#   "transformers_version": "4.42.3",
#   "use_cache": false,
#   "vocab_size": 32001
# }
#
# [INFO|tokenization_utils_base.py:2161] 2024-07-12 09:04:19,877 >> loading file tokenizer.model from cache at /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/hub/models--TinyLlama--TinyLlama-1.1B-Chat-v0.1/snapshots/7abc14e7779eabc3a028bc695342869d0410dea2/tokenizer.model
# [INFO|tokenization_utils_base.py:2161] 2024-07-12 09:04:19,879 >> loading file added_tokens.json from cache at /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/hub/models--TinyLlama--TinyLlama-1.1B-Chat-v0.1/snapshots/7abc14e7779eabc3a028bc695342869d0410dea2/added_tokens.json
# [INFO|tokenization_utils_base.py:2161] 2024-07-12 09:04:19,880 >> loading file special_tokens_map.json from cache at /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/hub/models--TinyLlama--TinyLlama-1.1B-Chat-v0.1/snapshots/7abc14e7779eabc3a028bc695342869d0410dea2/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2161] 2024-07-12 09:04:19,881 >> loading file tokenizer_config.json from cache at /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/hub/models--TinyLlama--TinyLlama-1.1B-Chat-v0.1/snapshots/7abc14e7779eabc3a028bc695342869d0410dea2/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2161] 2024-07-12 09:04:19,883 >> loading file tokenizer.json from cache at /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/hub/models--TinyLlama--TinyLlama-1.1B-Chat-v0.1/snapshots/7abc14e7779eabc3a028bc695342869d0410dea2/tokenizer.json
# Using custom data configuration default-5b83c21307ab0159
# 2024-07-12 09:04:20,301 - builder.py - datasets.builder - INFO - Using custom data configuration default-5b83c21307ab0159
# Loading Dataset Infos from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.local/lib/python3.9/site-packages/datasets/packaged_modules/json
# 2024-07-12 09:04:20,305 - info.py - datasets.info - INFO - Loading Dataset Infos from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.local/lib/python3.9/site-packages/datasets/packaged_modules/json
# Overwrite dataset info from restored data version if exists.
# 2024-07-12 09:04:20,319 - builder.py - datasets.builder - INFO - Overwrite dataset info from restored data version if exists.
# Loading Dataset info from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a
# 2024-07-12 09:04:20,324 - info.py - datasets.info - INFO - Loading Dataset info from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a
# Found cached dataset json (/home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a)
# 2024-07-12 09:04:20,337 - builder.py - datasets.builder - INFO - Found cached dataset json (/home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a)
# Loading Dataset info from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a
# 2024-07-12 09:04:20,340 - info.py - datasets.info - INFO - Loading Dataset info from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a
# Using custom data configuration default-5b83c21307ab0159
# 2024-07-12 09:04:20,612 - builder.py - datasets.builder - INFO - Using custom data configuration default-5b83c21307ab0159
# Loading Dataset Infos from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.local/lib/python3.9/site-packages/datasets/packaged_modules/json
# 2024-07-12 09:04:20,616 - info.py - datasets.info - INFO - Loading Dataset Infos from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.local/lib/python3.9/site-packages/datasets/packaged_modules/json
# Overwrite dataset info from restored data version if exists.
# 2024-07-12 09:04:20,624 - builder.py - datasets.builder - INFO - Overwrite dataset info from restored data version if exists.
# Loading Dataset info from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a
# 2024-07-12 09:04:20,626 - info.py - datasets.info - INFO - Loading Dataset info from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a
# Found cached dataset json (/home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a)
# 2024-07-12 09:04:20,636 - builder.py - datasets.builder - INFO - Found cached dataset json (/home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a)
# Loading Dataset info from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a
# 2024-07-12 09:04:20,638 - info.py - datasets.info - INFO - Loading Dataset info from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a
# Using custom data configuration default-5b83c21307ab0159
# 2024-07-12 09:04:20,899 - builder.py - datasets.builder - INFO - Using custom data configuration default-5b83c21307ab0159
# Loading Dataset Infos from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.local/lib/python3.9/site-packages/datasets/packaged_modules/json
# 2024-07-12 09:04:20,902 - info.py - datasets.info - INFO - Loading Dataset Infos from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.local/lib/python3.9/site-packages/datasets/packaged_modules/json
# Overwrite dataset info from restored data version if exists.
# 2024-07-12 09:04:20,910 - builder.py - datasets.builder - INFO - Overwrite dataset info from restored data version if exists.
# Loading Dataset info from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a
# 2024-07-12 09:04:20,913 - info.py - datasets.info - INFO - Loading Dataset info from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a
# Found cached dataset json (/home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a)
# 2024-07-12 09:04:20,922 - builder.py - datasets.builder - INFO - Found cached dataset json (/home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a)
# Loading Dataset info from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a
# 2024-07-12 09:04:20,925 - info.py - datasets.info - INFO - Loading Dataset info from /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a
# [INFO|modeling_utils.py:3556] 2024-07-12 09:04:21,149 >> loading weights file model.safetensors from cache at /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/hub/models--TinyLlama--TinyLlama-1.1B-Chat-v0.1/snapshots/7abc14e7779eabc3a028bc695342869d0410dea2/model.safetensors
# [INFO|modeling_utils.py:1531] 2024-07-12 09:04:21,166 >> Instantiating LlamaForCausalLM model under default dtype torch.bfloat16.
# [INFO|configuration_utils.py:1000] 2024-07-12 09:04:21,172 >> Generate config GenerationConfig {
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "use_cache": false
# }
#
# [INFO|modeling_utils.py:4364] 2024-07-12 09:04:22,248 >> All model checkpoint weights were used when initializing LlamaForCausalLM.
#
# [INFO|modeling_utils.py:4372] 2024-07-12 09:04:22,249 >> All the weights of LlamaForCausalLM were initialized from the model checkpoint at TinyLlama/TinyLlama-1.1B-Chat-v0.1.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use LlamaForCausalLM for predictions without further training.
# [INFO|configuration_utils.py:955] 2024-07-12 09:04:22,363 >> loading configuration file generation_config.json from cache at /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/hub/models--TinyLlama--TinyLlama-1.1B-Chat-v0.1/snapshots/7abc14e7779eabc3a028bc695342869d0410dea2/generation_config.json
# [INFO|configuration_utils.py:1000] 2024-07-12 09:04:22,365 >> Generate config GenerationConfig {
#   "max_new_tokens": 32
# }
#
# Loading cached processed dataset at /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a/cache-23ab305b0cef0a6f.arrow
# 2024-07-12 09:04:22,581 - arrow_dataset.py - datasets.arrow_dataset - INFO - Loading cached processed dataset at /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a/cache-23ab305b0cef0a6f.arrow
# Loading cached processed dataset at /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a/cache-ab7e3e5c7d05f932.arrow
# 2024-07-12 09:04:22,593 - arrow_dataset.py - datasets.arrow_dataset - INFO - Loading cached processed dataset at /home/ueb85a29a9d9eddd1758cc2b8dbb4c61/.cache/huggingface/datasets/json/default-5b83c21307ab0159/0.0.0/7483f22a71512872c377524b97484f6d20c275799bb9e7cd8fb3198178d8220a/cache-ab7e3e5c7d05f932.arrow
# 2024-07-12 09:04:22,596 - finetuning.py - intel_extension_for_transformers.transformers.llm.finetuning.finetuning - INFO - Using data collator of type DataCollatorForSeq2Seq
# [INFO|trainer.py:642] 2024-07-12 09:04:22,798 >> Using cpu_amp half precision backend
# trainable params: 1,126,400 || all params: 1,101,178,880 || trainable%: 0.10229037447576184
# [INFO|trainer.py:2128] 2024-07-12 09:04:23,048 >> ***** Running training *****
# [INFO|trainer.py:2129] 2024-07-12 09:04:23,049 >>   Num examples = 1,980
# [INFO|trainer.py:2130] 2024-07-12 09:04:23,050 >>   Num Epochs = 3
# [INFO|trainer.py:2131] 2024-07-12 09:04:23,051 >>   Instantaneous batch size per device = 4
# [INFO|trainer.py:2134] 2024-07-12 09:04:23,053 >>   Total train batch size (w. parallel, distributed & accumulation) = 8
# [INFO|trainer.py:2135] 2024-07-12 09:04:23,053 >>   Gradient Accumulation steps = 2
# [INFO|trainer.py:2136] 2024-07-12 09:04:23,055 >>   Total optimization steps = 741
# [INFO|trainer.py:2137] 2024-07-12 09:04:23,057 >>   Number of trainable parameters = 1,126,400
#     <div>
#
#       <progress value='741' max='741' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [741/741 40:33, Epoch 2/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>500</td>
#       <td>1.338800</td>
#     </tr>
#   </tbody>
# </table><p>
# [INFO|trainer.py:2383] 2024-07-12 09:45:01,829 >>
#
# Training completed. Do not forget to share your model on huggingface.co/models =)
#
#
# [INFO|trainer.py:3478] 2024-07-12 09:45:01,835 >> Saving model checkpoint to ./tmp1
# [INFO|tokenization_utils_base.py:2574] 2024-07-12 09:45:01,862 >> tokenizer config file saved in ./tmp1/tokenizer_config.json
# [INFO|tokenization_utils_base.py:2583] 2024-07-12 09:45:01,864 >> Special tokens file saved in ./tmp1/special_tokens_map.json
# [INFO|tokenization_utils_base.py:2634] 2024-07-12 09:45:01,866 >> added tokens file saved in ./tmp1/added_tokens.json
# 2024-07-12 09:45:01,872 - finetuning.py - intel_extension_for_transformers.transformers.llm.finetuning.finetuning - INFO - *** Evaluate After Training***
# [INFO|trainer.py:3788] 2024-07-12 09:45:01,877 >>
# ***** Running Evaluation *****
# [INFO|trainer.py:3790] 2024-07-12 09:45:01,878 >>   Num examples = 20
# [INFO|trainer.py:3793] 2024-07-12 09:45:01,879 >>   Batch size = 4
#     <div>
#
#       <progress value='5' max='5' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [5/5 00:01]
#     </div>
# ***** eval metrics *****
#   epoch                   =     2.9939
#   eval_loss               =     1.2145
#   eval_ppl                =     3.3685
#   eval_runtime            = 0:00:01.88
#   eval_samples            =         20
#   eval_samples_per_second =     10.611
#   eval_steps_per_second   =      2.653
